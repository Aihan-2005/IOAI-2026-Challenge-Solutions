# %%
from __future__ import annotations

import subprocess
import sys
from pathlib import Path


REPO_URL = (
    "https://github.com/"
    "Aihan-2005/"
    "IOAI-2026-Challenge-Solutions.git"
)

BRANCH = "task1-find-the-order"

RUNTIME_ROOT = Path("/content")

REPO_DIR = (
    RUNTIME_ROOT
    / "IOAI-2026-Challenge-Solutions"
)

TASK_DIR = (
    REPO_DIR
    / "task1-find-the-order"
)


def run(
    command: list[str],
    *,
    cwd: Path | None = None,
) -> None:
    print(
        "$",
        " ".join(command),
    )

    subprocess.run(
        command,
        cwd=(
            str(cwd)
            if cwd is not None
            else None
        ),
        check=True,
    )


if (
    REPO_DIR
    / ".git"
).is_dir():
    run(
        [
            "git",
            "fetch",
            "origin",
        ],
        cwd=REPO_DIR,
    )

    run(
        [
            "git",
            "checkout",
            BRANCH,
        ],
        cwd=REPO_DIR,
    )

    run(
        [
            "git",
            "pull",
            "--ff-only",
            "origin",
            BRANCH,
        ],
        cwd=REPO_DIR,
    )

else:
    run(
        [
            "git",
            "clone",
            "--branch",
            BRANCH,
            "--single-branch",
            REPO_URL,
            str(REPO_DIR),
        ]
    )


task_path = str(TASK_DIR)

if task_path not in sys.path:
    sys.path.insert(
        0,
        task_path,
    )


print()
print("Repository:", REPO_DIR)
print("Task:", TASK_DIR)
print("Python path:", sys.path[0])
# Out:
# $ git clone --branch task1-find-the-order --single-branch https://github.com/Aihan-2005/IOAI-2026-Challenge-Solutions.git /content/IOAI-2026-Challenge-Solutions
#
# Repository: /content/IOAI-2026-Challenge-Solutions
# Task: /content/IOAI-2026-Challenge-Solutions/task1-find-the-order
# Python path: /content/IOAI-2026-Challenge-Solutions/task1-find-the-order

# %%
import subprocess
import sys


requirements = (
    TASK_DIR
    / "requirements-gpu.txt"
)


subprocess.run(
    [
        sys.executable,
        "-m",
        "pip",
        "install",
        "-q",
        "-r",
        str(requirements),
    ],
    check=True,
)

print(
    "GPU dependencies installed."
)
# Out:
# GPU dependencies installed.

# %%
import torch


assert torch.cuda.is_available(), (
    "CUDA GPU is not available."
)

print(
    "Torch:",
    torch.__version__,
)

print(
    "GPU:",
    torch.cuda.get_device_name(0),
)


properties = (
    torch.cuda
    .get_device_properties(0)
)

print(
    "VRAM:",
    round(
        properties.total_memory
        / 1024**3,
        2,
    ),
    "GB",
)
# Out:
# Torch: 2.11.0+cu128
# GPU: Tesla T4
# VRAM: 14.56 GB

# %%
from src.hf_data import (
    download_hf_subset,
)


DATA_ROOT = Path(
    "/content/ioai-data"
)


downloaded = (
    download_hf_subset(
        subset="public/pretest",
        destination=DATA_ROOT,
    )
)


print(
    "Dataset root:",
    downloaded.dataset_root,
)

print(
    "Split:",
    downloaded.split_dir,
)

print(
    "Answers:",
    downloaded.answers_path,
)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:138: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
#   warnings.warn(f"\nError while fetching `HF_TOKEN` secret value from your vault: '{str(e)}'.")
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 218 files:   0%|          | 0/218 [00:00<?, ?it/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Dataset root: /content/ioai-data
# Split: /content/ioai-data/public/pretest
# Answers: /content/ioai-data/public/pretest_answers.json

# %%
from src.dataset_io import (
    load_dialogues,
)


dialogues = load_dialogues(
    downloaded.split_dir
)


print(
    "Dialogues:",
    len(dialogues),
)


first_dialogue = dialogues[0]


print(
    "First dialogue ID:",
    first_dialogue.dialogue_id,
)

print(
    "Chunks:",
    first_dialogue.n_chunks,
)

print(
    "Prefix:",
    first_dialogue.prefix,
)


for path in (
    first_dialogue.chunk_paths
):
    print(
        path.name
    )
# Out:
# Dialogues: 20
# First dialogue ID: 11
# Chunks: 7
# Prefix: (5, 2)
# chunk_0.wav
# chunk_1.wav
# chunk_2.wav
# chunk_3.wav
# chunk_4.wav
# chunk_5.wav
# chunk_6.wav

# %%
from src.asr_whisper import (
    WhisperConfig,
    WhisperTranscriber,
)


transcriber = (
    WhisperTranscriber(
        WhisperConfig(
            model_id=(
                "openai/whisper-small"
            )
        )
    )
)


print(
    "Device:",
    transcriber.device,
)

print(
    "DType:",
    transcriber.dtype,
)
# Out:
# preprocessor_config.json:   0%|          | 0.00/185k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.97k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/283k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/836k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.48M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/34.6k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.19k [00:00<?, ?B/s]
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors: reconstructing file:   0%|          |  0.00B /  967MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/479 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/3.87k [00:00<?, ?B/s]
# Device: cuda
# DType: torch.float16

# %%
audio_path = (
    first_dialogue
    .chunk_paths[0]
)


print(
    "Audio:",
    audio_path,
)


text = (
    transcriber
    .transcribe_file(
        str(audio_path)
    )
)


print()
print(
    "TRANSCRIPT:"
)

print(
    text
)
# Out:
# Audio: /content/ioai-data/public/pretest/11/chunk_0.wav
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] A custom logits processor of type <class 'transformers.generation.logits_process.SuppressTokensLogitsProcessor'> has been passed to `.generate()`, but it was also created in `.generate()`, given its parameterization. The custom <class 'transformers.generation.logits_process.SuppressTokensLogitsProcessor'> will take precedence. Please check the docstring of <class 'transformers.generation.logits_process.SuppressTokensLogitsProcessor'> to see related `.generate()` flags.
# [transformers] A custom logits processor of type <class 'transformers.generation.logits_process.SuppressTokensAtBeginLogitsProcessor'> has been passed to `.generate()`, but it was also created in `.generate()`, given its parameterization. The custom <class 'transformers.generation.logits_process.SuppressTokensAtBeginLogitsProcessor'> will take precedence. Please check the docstring of <class 'transformers.generation.logits_process.SuppressTokensAtBeginLogitsProcessor'> to see related `.generate()` flags.
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer WhisperTokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# TRANSCRIPT:
# Wow, I'm very excited about your ceremony.

# %%
import subprocess

subprocess.run(
    [
        "git",
        "pull",
        "--ff-only",
        "origin",
        "task1-find-the-order",
    ],
    cwd=str(REPO_DIR),
    check=True,
)
# Out:
# CompletedProcess(args=['git', 'pull', '--ff-only', 'origin', 'task1-find-the-order'], returncode=0)

# %%
ARTIFACT_ROOT = Path(
    "/content/ioai-artifacts"
)

TRANSCRIPT_DIR = (
    ARTIFACT_ROOT
    / "transcripts"
    / "whisper-small"
    / "pretest"
)

REPORT_DIR = (
    ARTIFACT_ROOT
    / "reports"
)

TRANSCRIPT_DIR.mkdir(
    parents=True,
    exist_ok=True,
)

REPORT_DIR.mkdir(
    parents=True,
    exist_ok=True,
)

print(
    "Transcript cache:",
    TRANSCRIPT_DIR,
)

print(
    "Reports:",
    REPORT_DIR,
)
# Out:
# Transcript cache: /content/ioai-artifacts/transcripts/whisper-small/pretest
# Reports: /content/ioai-artifacts/reports

# %%
from src.transcript_io import (
    TranscriptStore,
)

from src.transcription_runner import (
    populate_transcript_cache,
)


store = TranscriptStore(
    TRANSCRIPT_DIR
)

stats = populate_transcript_cache(
    dialogues=(
        first_dialogue,
    ),
    transcriber=transcriber,
    store=store,
)

print(stats)
# Out:
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [1/1] [ASR] dialogue=11 chunks=7
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# TranscriptionStats(total_dialogues=1, transcribed_dialogues=1, cached_dialogues=0, elapsed_seconds=1.3179364910000686)

# %%
transcript = store.load(
    first_dialogue.dialogue_id
)

for chunk in transcript.chunks:
    print(
        f"[{chunk.chunk_index:02d}] "
        f"{chunk.text}"
    )
# Out:
# [00] Wow, I'm very excited about your ceremony.
# [01] Yeah, I did. But my fiancé has an important project.
# [02] We plan our wedding for next May!
# [03] Why so late? Didn't she want to get married this October?
# [04] Julie's friend Mary and John will be the best men.
# [05] When are you getting married?
# [06] That's really a shame. By the way, who will be the price maid?

# %%
from src.evaluation_io import (
    load_rank_answers,
)

from src.predictors import (
    PrefixIndexBaseline,
    TranscriptOrderingPredictor,
)

from src.heuristic_scorer import (
    HeuristicDialogueTransitionScorer,
)

from src.order_utils import (
    pairwise_score,
)


assert downloaded.answers_path is not None


targets = load_rank_answers(
    downloaded.answers_path
)


truth = targets[
    first_dialogue.dialogue_id
]


baseline_predictor = (
    PrefixIndexBaseline()
)


semantic_predictor = (
    TranscriptOrderingPredictor(
        transcript_store=store,
        transition_scorer=(
            HeuristicDialogueTransitionScorer()
        ),
        beam_width=32,
    )
)


baseline_rank = (
    baseline_predictor.predict(
        first_dialogue
    )
)


semantic_rank = (
    semantic_predictor.predict(
        first_dialogue
    )
)


baseline_score = (
    pairwise_score(
        baseline_rank,
        truth,
    )
)


semantic_score = (
    pairwise_score(
        semantic_rank,
        truth,
    )
)


print(
    "Dialogue:",
    first_dialogue.dialogue_id,
)

print(
    "Truth:",
    truth,
)

print(
    "Baseline:",
    baseline_rank,
)

print(
    "Whisper + heuristic:",
    semantic_rank,
)

print()

print(
    "Baseline score:",
    f"{100 * baseline_score:.2f}",
)

print(
    "Whisper + heuristic score:",
    f"{100 * semantic_score:.2f}",
)
# Out:
# Dialogue: 11
# Truth: [6, 3, 1, 2, 5, 0, 4]
# Baseline: [2, 3, 1, 4, 5, 0, 6]
# Whisper + heuristic: [2, 4, 1, 3, 6, 0, 5]
#
# Baseline score: 71.43
# Whisper + heuristic score: 80.95

# %%
from src.benchmark import (
    evaluate_predictor,
)


pretest_dialogues = load_dialogues(
    downloaded.split_dir
)


stats = populate_transcript_cache(
    dialogues=pretest_dialogues,
    transcriber=transcriber,
    store=store,
)

print(stats)
# Out:
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [1/20] [CACHE] dialogue=11
# [2/20] [ASR] dialogue=69 chunks=18
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [3/20] [ASR] dialogue=202 chunks=10
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [4/20] [ASR] dialogue=268 chunks=9
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [5/20] [ASR] dialogue=340 chunks=17
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [6/20] [ASR] dialogue=384 chunks=8
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [7/20] [ASR] dialogue=446 chunks=9
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [8/20] [ASR] dialogue=456 chunks=7
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [9/20] [ASR] dialogue=570 chunks=13
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [10/20] [ASR] dialogue=577 chunks=9
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [11/20] [ASR] dialogue=649 chunks=8
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [12/20] [ASR] dialogue=656 chunks=14
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [13/20] [ASR] dialogue=682 chunks=15
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [14/20] [ASR] dialogue=697 chunks=12
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [15/20] [ASR] dialogue=1149 chunks=10
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [16/20] [ASR] dialogue=1257 chunks=8
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [17/20] [ASR] dialogue=1385 chunks=16
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [18/20] [ASR] dialogue=1401 chunks=11
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [19/20] [ASR] dialogue=1448 chunks=8
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [20/20] [ASR] dialogue=1494 chunks=7
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# TranscriptionStats(total_dialogues=20, transcribed_dialogues=19, cached_dialogues=1, elapsed_seconds=39.37789407799994)

# %%
baseline_benchmark = (
    evaluate_predictor(
        dialogues=pretest_dialogues,
        targets=targets,
        predictor=(
            PrefixIndexBaseline()
        ),
    )
)


semantic_benchmark = (
    evaluate_predictor(
        dialogues=pretest_dialogues,
        targets=targets,
        predictor=(
            semantic_predictor
        ),
    )
)


print(
    "Official baseline:",
    f"{baseline_benchmark.mean_score:.2f}",
)


print(
    "Whisper + heuristic:",
    f"{semantic_benchmark.mean_score:.2f}",
)
# Out:
# Official baseline: 68.95
# Whisper + heuristic: 73.45

# %%
from src.analysis import (
    compare_predictors,
    worst_dialogues,
)


print(
    "Worst semantic cases:"
)

for result in worst_dialogues(
    semantic_benchmark,
    limit=5,
):
    print(
        f"id={result.dialogue_id:<4} "
        f"chunks={result.n_chunks:<2} "
        f"score={100 * result.score:.2f}"
    )


print()
print(
    "Candidate vs baseline:"
)


for dialogue_id, delta in (
    compare_predictors(
        baseline=baseline_benchmark,
        candidate=semantic_benchmark,
    )
):
    print(
        f"id={dialogue_id:<4} "
        f"delta={100 * delta:+.2f}"
    )
# Out:
# Worst semantic cases:
# id=384  chunks=8  score=57.14
# id=202  chunks=10 score=57.78
# id=340  chunks=17 score=62.50
# id=1257 chunks=8  score=64.29
# id=682  chunks=15 score=64.76
#
# Candidate vs baseline:
# id=1257 delta=-21.43
# id=1149 delta=-6.67
# id=1401 delta=-5.45
# id=340  delta=-5.15
# id=202  delta=-4.44
# id=268  delta=+0.00
# id=649  delta=+0.00
# id=69   delta=+1.31
# id=384  delta=+3.57
# id=682  delta=+3.81
# id=1494 delta=+4.76
# id=656  delta=+5.49
# id=697  delta=+6.06
# id=11   delta=+9.52
# id=1448 delta=+10.71
# id=1385 delta=+12.50
# id=456  delta=+14.29
# id=570  delta=+16.67
# id=446  delta=+16.67
# id=577  delta=+27.78

# %%
import subprocess

subprocess.run(
    [
        "git",
        "pull",
        "--ff-only",
        "origin",
        "task1-find-the-order",
    ],
    cwd=str(REPO_DIR),
    check=True,
)
# Out:
# CompletedProcess(args=['git', 'pull', '--ff-only', 'origin', 'task1-find-the-order'], returncode=0)

# %%
import subprocess
import sys


DIAGNOSTIC_REPORT = (
    REPORT_DIR
    / "phase6_pretest_diagnostics.json"
)


command = [
    sys.executable,
    str(
        TASK_DIR
        / "scripts"
        / "phase6_diagnostics.py"
    ),
    "--split-dir",
    str(downloaded.split_dir),
    "--answers",
    str(downloaded.answers_path),
    "--transcript-dir",
    str(TRANSCRIPT_DIR),
    "--output",
    str(DIAGNOSTIC_REPORT),
    "--max-dialogues",
    "20",
    "--beam-width",
    "32",
    "--show-failures",
    "3",
]


result = subprocess.run(
    command,
    text=True,
    capture_output=True,
)


print(result.stdout)


if result.stderr:
    print(
        "\n--- STDERR ---\n"
    )
    print(result.stderr)


if result.returncode != 0:
    raise RuntimeError(
        f"Diagnostics failed with "
        f"return code {result.returncode}"
    )


print(
    "\nDiagnostic report:",
    DIAGNOSTIC_REPORT,
)
# Out:
# ================================================================================
# PHASE 6 — SCORER / SEARCH DIAGNOSTICS
# ================================================================================
# Scorer: heuristic-dialogue-v1
# Predictor: transcript-beam-heuristic-dialogue-v1
# Dialogues: 20
# Non-trivial decisions: 156
#
# Local next-turn Top-1: 30.77%
# Local next-turn MRR: 0.5164
# Mean true-vs-best-wrong margin: -0.2731
#
# Global pairwise score: 73.45
# Gold path scored above beam prediction: 0.00%
#
# ================================================================================
# WORST GLOBAL CASES
# ================================================================================
#
# Score: 57.14
# Gold path score: 2.7500
# Predicted path score: 3.2310
# Gold > predicted objective: False
#
# ================================================================================
# Dialogue 384
# Chunks: 8
# Prefix: (2, 0)
#
# TRUE ORDER:
# 00. chunk_2  | Hey Jim, you're 15 minutes late. What's up?
# 01. chunk_0  | I got stuck in a traffic jam.
# 02. chunk_7  | Hurry up, the show is about to start.
# 03. chunk_6  | It looks like you're very interested in the circus.
# 04. chunk_5  | Yes, I love to see the animal show.
# 05. chunk_1  | I have never seen those before, but since you're so excited, it should be good.
# 06. chunk_4  | I'm sure you love it.
# 07. chunk_3  | Okay, I'll go and get some popcorn first.
#
# PREDICTED ORDER:
# 00. chunk_2  | Hey Jim, you're 15 minutes late. What's up?
# 01. chunk_0  | I got stuck in a traffic jam.
# 02. chunk_3  | Okay, I'll go and get some popcorn first.
# 03. chunk_4  | I'm sure you love it.
# 04. chunk_5  | Yes, I love to see the animal show.
# 05. chunk_7  | Hurry up, the show is about to start.
# 06. chunk_1  | I have never seen those before, but since you're so excited, it should be good.
# 07. chunk_6  | It looks like you're very interested in the circus.
# ================================================================================
#
# Score: 57.78
# Gold path score: 8.2500
# Predicted path score: 8.4643
# Gold > predicted objective: False
#
# ================================================================================
# Dialogue 202
# Chunks: 10
# Prefix: (6, 3)
#
# TRUE ORDER:
# 00. chunk_6  | How about a movie tonight?
# 01. chunk_3  | It doesn't matter to me.
# 02. chunk_8  | Does 7 o'clock suit you?
# 03. chunk_5  | Um, either way, I don't care.
# 04. chunk_7  | How about a snack after work?
# 05. chunk_2  | I couldn't care less.
# 06. chunk_0  | Would you rather stay home?
# 07. chunk_4  | Whatever you say.
# 08. chunk_1  | Are you really interested in doing something?
# 09. chunk_9  | I don't mind if you want to.
#
# PREDICTED ORDER:
# 00. chunk_6  | How about a movie tonight?
# 01. chunk_3  | It doesn't matter to me.
# 02. chunk_0  | Would you rather stay home?
# 03. chunk_1  | Are you really interested in doing something?
# 04. chunk_9  | I don't mind if you want to.
# 05. chunk_7  | How about a snack after work?
# 06. chunk_2  | I couldn't care less.
# 07. chunk_5  | Um, either way, I don't care.
# 08. chunk_8  | Does 7 o'clock suit you?
# 09. chunk_4  | Whatever you say.
# ================================================================================
#
# Score: 62.50
# Gold path score: 10.0350
# Predicted path score: 13.6877
# Gold > predicted objective: False
#
# ================================================================================
# Dialogue 340
# Chunks: 17
# Prefix: (11, 1)
#
# TRUE ORDER:
# 00. chunk_11 | Are you ready to go to the supermarket?
# 01. chunk_1  | Yes, are you?
# 02. chunk_2  | I've got my money and my kids, so I'm ready.
# 03. chunk_3  | You do know that it's absolutely freezing out, don't you? I'd put a coat on if I wore you.
# 04. chunk_10 | It wasn't called out this morning.
# 05. chunk_4  | Well, it started raining since then. Look out the window. It's pouring rain out there.
# 06. chunk_15 | Have a look outside for me. Does that look like hell to you?
# 07. chunk_12 | It does actually. Maybe we should wait for it to clear up before we go shopping.
# 08. chunk_14 | That's a good idea, but maybe we should move the car so that the hail doesn't dent it.
# 09. chunk_6  | Okay, I'll go move the car if you turn the heat on. It's a bit chilly in here.
# 10. chunk_8  | How long do you think this hail storm is supposed to last?
# 11. chunk_5  | I don't know. The weatherman didn't say anything about this in his weather report last night.
# 12. chunk_9  | Maybe we should turn on the news in case it's supposed to get worse.
# 13. chunk_13 | I don't think we have anything to worry about. Do you want to put on a cup of tea as well?
# 14. chunk_7  | Good idea, that will help us to warm up.
# 15. chunk_16 | If I'm not back in 10 minutes, come and find me.
# 16. chunk_0  | Alright, I'll have a cup of tea waiting for you.
#
# PREDICTED ORDER:
# 00. chunk_11 | Are you ready to go to the supermarket?
# 01. chunk_1  | Yes, are you?
# 02. chunk_13 | I don't think we have anything to worry about. Do you want to put on a cup of tea as well?
# 03. chunk_5  | I don't know. The weatherman didn't say anything about this in his weather report last night.
# 04. chunk_8  | How long do you think this hail storm is supposed to last?
# 05. chunk_10 | It wasn't called out this morning.
# 06. chunk_15 | Have a look outside for me. Does that look like hell to you?
# 07. chunk_12 | It does actually. Maybe we should wait for it to clear up before we go shopping.
# 08. chunk_9  | Maybe we should turn on the news in case it's supposed to get worse.
# 09. chunk_6  | Okay, I'll go move the car if you turn the heat on. It's a bit chilly in here.
# 10. chunk_4  | Well, it started raining since then. Look out the window. It's pouring rain out there.
# 11. chunk_3  | You do know that it's absolutely freezing out, don't you? I'd put a coat on if I wore you.
# 12. chunk_16 | If I'm not back in 10 minutes, come and find me.
# 13. chunk_2  | I've got my money and my kids, so I'm ready.
# 14. chunk_14 | That's a good idea, but maybe we should move the car so that the hail doesn't dent it.
# 15. chunk_7  | Good idea, that will help us to warm up.
# 16. chunk_0  | Alright, I'll have a cup of tea waiting for you.
# ================================================================================
#
# ================================================================================
# REPORT
# ================================================================================
# Saved: /content/ioai-artifacts/reports/phase6_pretest_diagnostics.json
#
#
# Diagnostic report: /content/ioai-artifacts/reports/phase6_pretest_diagnostics.json

# %%
import json


assert DIAGNOSTIC_REPORT.is_file(), (
    f"Diagnostic report not found: "
    f"{DIAGNOSTIC_REPORT}"
)


diagnostics = json.loads(
    DIAGNOSTIC_REPORT.read_text(
        encoding="utf-8"
    )
)


print(
    "Scorer:",
    diagnostics["scorer_name"],
)

print(
    "Predictor:",
    diagnostics["predictor_name"],
)

print(
    "Dialogues:",
    diagnostics["dialogue_count"],
)

print(
    "Non-trivial decisions:",
    diagnostics["decision_count"],
)

print()

print(
    "Local next-turn Top-1:",
    f"{100 * diagnostics['local_top1_accuracy']:.2f}%",
)

print(
    "Local next-turn MRR:",
    f"{diagnostics['local_mrr']:.4f}",
)

print(
    "Mean true-vs-best-wrong margin:",
    f"{diagnostics['mean_true_margin']:+.4f}",
)

print()

print(
    "Global pairwise score:",
    f"{diagnostics['mean_pairwise_score']:.2f}",
)

print(
    "Gold path scored above beam prediction:",
    (
        f"{100 * diagnostics['gold_path_beats_prediction_rate']:.2f}%"
    ),
)
# Out:
# Scorer: heuristic-dialogue-v1
# Predictor: transcript-beam-heuristic-dialogue-v1
# Dialogues: 20
# Non-trivial decisions: 156
#
# Local next-turn Top-1: 30.77%
# Local next-turn MRR: 0.5164
# Mean true-vs-best-wrong margin: -0.2731
#
# Global pairwise score: 73.45
# Gold path scored above beam prediction: 0.00%

# %%
dialogue_reports = (
    diagnostics["dialogues"]
)


worst_cases = sorted(
    dialogue_reports,
    key=lambda item: (
        item["pairwise_score"],
        -item["n_chunks"],
        int(item["dialogue_id"]),
    ),
)[:5]


print(
    "Worst diagnostic cases:"
)

print()


for item in worst_cases:
    print(
        f"Dialogue {item['dialogue_id']}"
    )

    print(
        f"  chunks: "
        f"{item['n_chunks']}"
    )

    print(
        f"  pairwise score: "
        f"{100 * item['pairwise_score']:.2f}"
    )

    print(
        f"  gold path score: "
        f"{item['gold_path_score']:.4f}"
    )

    print(
        f"  predicted path score: "
        f"{item['predicted_path_score']:.4f}"
    )

    print(
        f"  gold > predicted objective: "
        f"{item['gold_path_beats_prediction']}"
    )

    print(
        f"  true order: "
        f"{item['truth_order']}"
    )

    print(
        f"  predicted order: "
        f"{item['predicted_order']}"
    )

    print()
# Out:
# Worst diagnostic cases:
#
# Dialogue 384
#   chunks: 8
#   pairwise score: 57.14
#   gold path score: 2.7500
#   predicted path score: 3.2310
#   gold > predicted objective: False
#   true order: [2, 0, 7, 6, 5, 1, 4, 3]
#   predicted order: [2, 0, 3, 4, 5, 7, 1, 6]
#
# Dialogue 202
#   chunks: 10
#   pairwise score: 57.78
#   gold path score: 8.2500
#   predicted path score: 8.4643
#   gold > predicted objective: False
#   true order: [6, 3, 8, 5, 7, 2, 0, 4, 1, 9]
#   predicted order: [6, 3, 0, 1, 9, 7, 2, 5, 8, 4]
#
# Dialogue 340
#   chunks: 17
#   pairwise score: 62.50
#   gold path score: 10.0350
#   predicted path score: 13.6877
#   gold > predicted objective: False
#   true order: [11, 1, 2, 3, 10, 4, 15, 12, 14, 6, 8, 5, 9, 13, 7, 16, 0]
#   predicted order: [11, 1, 13, 5, 8, 10, 15, 12, 9, 6, 4, 3, 16, 2, 14, 7, 0]
#
# Dialogue 1257
#   chunks: 8
#   pairwise score: 64.29
#   gold path score: 1.3750
#   predicted path score: 2.9688
#   gold > predicted objective: False
#   true order: [3, 7, 2, 1, 0, 5, 4, 6]
#   predicted order: [3, 7, 4, 5, 0, 1, 2, 6]
#
# Dialogue 682
#   chunks: 15
#   pairwise score: 64.76
#   gold path score: 11.6876
#   predicted path score: 12.3438
#   gold > predicted objective: False
#   true order: [12, 13, 7, 10, 4, 6, 3, 5, 11, 0, 9, 1, 14, 2, 8]
#   predicted order: [12, 13, 7, 10, 2, 14, 1, 3, 9, 5, 4, 0, 11, 8, 6]

# %%
top1 = diagnostics[
    "local_top1_accuracy"
]

mrr = diagnostics[
    "local_mrr"
]

margin = diagnostics[
    "mean_true_margin"
]

search_gap = diagnostics[
    "gold_path_beats_prediction_rate"
]


print("=== Bottleneck Diagnosis ===")
print()

print(
    f"Top-1:      {100 * top1:.2f}%"
)

print(
    f"MRR:        {mrr:.4f}"
)

print(
    f"Margin:     {margin:+.4f}"
)

print(
    f"Search gap: {100 * search_gap:.2f}%"
)

print()


if (
    top1 < 0.50
    and margin < 0
):
    diagnosis = (
        "SCORER BOTTLENECK"
    )

    explanation = (
        "The transition scorer frequently "
        "prefers a wrong next turn over the "
        "true next turn."
    )

elif (
    search_gap >= 0.25
    and top1 >= 0.50
):
    diagnosis = (
        "SEARCH / OBJECTIVE BOTTLENECK"
    )

    explanation = (
        "The scorer contains useful signal, "
        "but the global decoding strategy is "
        "not consistently recovering strong paths."
    )

else:
    diagnosis = (
        "MIXED BOTTLENECK"
    )

    explanation = (
        "Both scorer quality and global decoding "
        "likely need improvement."
    )


print(
    "Diagnosis:",
    diagnosis,
)

print(
    "Reason:",
    explanation,
)
# Out:
# === Bottleneck Diagnosis ===
#
# Top-1:      30.77%
# MRR:        0.5164
# Margin:     -0.2731
# Search gap: 0.00%
#
# Diagnosis: SCORER BOTTLENECK
# Reason: The transition scorer frequently prefers a wrong next turn over the true next turn.

# %%
import subprocess

subprocess.run(
    [
        "git",
        "pull",
        "--ff-only",
        "origin",
        "task1-find-the-order",
    ],
    cwd=str(REPO_DIR),
    check=True,
)
# Out:
# CompletedProcess(args=['git', 'pull', '--ff-only', 'origin', 'task1-find-the-order'], returncode=0)

# %%
import subprocess
import sys


command = [
    sys.executable,
    str(
        TASK_DIR
        / "scripts"
        / "phase6b_qwen_ablation.py"
    ),
    "--split-dir",
    str(
        downloaded.split_dir
    ),
    "--answers",
    str(
        downloaded.answers_path
    ),
    "--transcript-dir",
    str(
        TRANSCRIPT_DIR
    ),
    "--max-dialogues",
    "5",
    "--beam-width",
    "32",
    "--batch-size",
    "16",
]


result = subprocess.run(
    command,
    text=True,
    capture_output=True,
)


print(
    result.stdout
)


if result.stderr:
    print(
        result.stderr
    )


assert result.returncode == 0
# Out:
# ================================================================================
# LOADING QWEN
# ================================================================================
# Device: cuda
#
# ================================================================================
# CONTROLLED ABLATION
# ================================================================================
# Official baseline: 70.23
# Whisper + heuristic: 70.47
# Whisper + Qwen: 69.75
#
# Qwen vs heuristic: -0.72
# Qwen cache entries: 782
#
# ================================================================================
# QWEN DIAGNOSTICS
# ================================================================================
# Local next-turn Top-1: 32.61%
# Local next-turn MRR: 0.5329
# Mean true-vs-best-wrong margin: -0.2260
# Global pairwise score: 69.75
# Gold path scored above beam prediction: 0.00%
#
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]
# Loading weights:   0%|          | 1/290 [00:00<02:10,  2.21it/s]
# Loading weights:  55%|█████▌    | 160/290 [00:00<00:00, 381.11it/s]
# Loading weights:  87%|████████▋ | 252/290 [00:00<00:00, 408.80it/s]
# Loading weights: 100%|██████████| 290/290 [00:00<00:00, 346.11it/s]

# %% [markdown]
# # Find the Order — Baseline solution
#
# A **deterministic** baseline. It uses `prefix.json` — the two chunks known to come
# first — and leaves every other chunk in the order it was given.
#
# It writes **`answers.json`** at the repo root in the rank convention: `P[i]` is the
# predicted chronological position of `chunk_i.wav`.
#
# Replace the logic below with your own.

# %%
import os, json

TEST_DIR = "dataset/test_public"        # grade-time: hidden eval set is overlaid here
OUTPUT   = "answers.json"

# prefix.json ships with every split. answers.json does NOT exist in the hidden
# grading set -- never read it from TEST_DIR, or your notebook dies at grade time.
with open(os.path.join(TEST_DIR, "prefix.json")) as f:
    prefix = json.load(f)

def n_chunks(ddir):
    return sum(1 for f in os.listdir(ddir)
               if f.startswith("chunk_") and f.endswith(".wav"))

# Only numeric directories are dialogues -- skip strays such as .ipynb_checkpoints,
# which JupyterLab creates as soon as you open something inside the folder.
dialogue_ids = sorted(
    (d for d in os.listdir(TEST_DIR)
     if d.isdigit() and os.path.isdir(os.path.join(TEST_DIR, d))),
    key=int,
)

answers = {}
for did in dialogue_ids:
    n = n_chunks(os.path.join(TEST_DIR, did))
    first, second = prefix[did]
    order = [first, second] + [i for i in range(n) if i not in (first, second)]
    rank = [0] * n                      # rank[i] = position of chunk_i
    for pos, idx in enumerate(order):
        rank[idx] = pos
    answers[did] = rank

with open(OUTPUT, "w") as f:
    json.dump(answers, f)
print(f"wrote {OUTPUT}: {len(answers)} dialogues")

# %% [markdown]
# ## Additional Models & Libraries

# %% [markdown]
# ## wav2-vec2-base-960h

# %%
import os
os.environ["HF_HUB_OFFLINE"] = "1"
os.environ["TRANSFORMERS_OFFLINE"] = "1"

import numpy as np
import torch
import librosa
from transformers import Wav2Vec2Model, Wav2Vec2Processor

WAV2VEC_PATH = "models/wav2vec2-base-960h"
SAMPLE_AUDIO = "dataset/train/0/chunk_0.wav"
device = "cuda" if torch.cuda.is_available() else "cpu"

processor = Wav2Vec2Processor.from_pretrained(WAV2VEC_PATH)
model = Wav2Vec2Model.from_pretrained(WAV2VEC_PATH).to(device).eval()

audio, _ = librosa.load(SAMPLE_AUDIO, sr=16000)
inputs = processor(audio, sampling_rate=16000, return_tensors="pt")
with torch.no_grad():
    h = model(inputs.input_values.to(device)).last_hidden_state
embed = h.mean(dim=1).squeeze().cpu().numpy()

print(f"Wav2vec embedding shape: {embed.shape}")

# %% [markdown]
# ## Qwen2.5-0.5B

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

QWEN25_MODEL_PATH = "models/qwen2.5-0.5b"
device = "cuda" if torch.cuda.is_available() else "cpu"

tokenizer = AutoTokenizer.from_pretrained(QWEN25_MODEL_PATH)
model = AutoModelForCausalLM.from_pretrained(QWEN25_MODEL_PATH, dtype=torch.bfloat16).to(device).eval()

prompt = "The weather today is"
ids = tokenizer(prompt, return_tensors="pt").input_ids.to(device)
with torch.no_grad():
    out = model.generate(ids, max_new_tokens=20, do_sample=False)
print(tokenizer.decode(out[0], skip_special_tokens=True))

# %% [markdown]
# ## Whisper-small

# %%
import torch
import librosa
from transformers import WhisperForConditionalGeneration, WhisperProcessor

WHISPER_MODEL_PATH = "models/whisper-small"
SAMPLE_AUDIO = "dataset/train/0/chunk_0.wav"

processor = WhisperProcessor.from_pretrained(WHISPER_MODEL_PATH)
model = WhisperForConditionalGeneration.from_pretrained(WHISPER_MODEL_PATH).to(device).eval()


audio, _ = librosa.load(SAMPLE_AUDIO, sr=16000)
feats = processor(audio, sampling_rate=16000, return_tensors="pt").input_features
with torch.no_grad():
    ids = model.generate(feats.to(device), language="en", task="transcribe")
result = processor.batch_decode(ids, skip_special_tokens=True)[0].strip()
print(f"Whisper ASR trasncription: {result}")
